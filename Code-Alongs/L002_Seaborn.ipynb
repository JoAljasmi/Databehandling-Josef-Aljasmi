# %%
import seaborn as sns

# %%
tips = sns.load_dataset(("tips"))
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.relplot(x="total_bill", y="tip", hue="sex",style="smoker", size="size",row="day", data=tips)
